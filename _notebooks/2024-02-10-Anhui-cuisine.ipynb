# %% [markdown]
# ---
# comments: true
# layout: notebook
# title: Anhui cuisine
# description: Discription about Anhui cuisine
# type: tangibles
# courses: { csp: {week: 0} }
# categories: [C4.1]
# tags:
# - APCSP
# - CODE CODE CODE
# ---

# %% [markdown]
# ## 7. Anhui cuisine
# ![image.png](attachment:image.png)
