# %% [markdown]
# ---
# comments: true
# layout: notebook
# title: Zhejiang cuisine
# description: Discription about Zhejiang cuisine
# type: tangibles
# courses: { csp: {week: 0} }
# categories: [C4.1]
# tags:
# - APCSP
# - CODE CODE CODE
# ---

# %% [markdown]
# ## 6. Zhejiang cuisine
# ![image.png](attachment:image.png)
