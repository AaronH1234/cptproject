# %% [markdown]
# ---
# comments: true
# layout: notebook
# title: Fujian cuisine
# description: Discription about Fujian cuisine
# type: tangibles
# courses: { csp: {week: 0} }
# categories: [C4.1]
# tags:
# - APCSP
# - CODE CODE CODE
# ---

# %% [markdown]
# ## 4. Fujian cuisine
# ![image.png](attachment:image.png)
