# %% [markdown]
# ---
# comments: true
# layout: notebook
# title: Shandong cuisine
# description: Discription about Shandong cuisine
# type: tangibles
# courses: { csp: {week: 0} }
# categories: [C4.1]
# tags:
# - APCSP
# - CODE CODE CODE
# ---

# %% [markdown]
# ## 8. Shandong cuisine
# ![image.png](attachment:image.png)
