# %% [markdown]
# ---
# comments: true
# layout: notebook
# title: Hunan-cuisine
# description: Discription about Hunan-cuisine
# type: tangibles
# courses: { csp: {week: 0} }
# categories: [C4.1]
# tags:
# - APCSP
# - CODE CODE CODE
# ---

# %% [markdown]
# ## 2. Hunan-cuisine
# ![image.png](attachment:image.png)
