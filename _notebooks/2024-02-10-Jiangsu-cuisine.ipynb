# %% [markdown]
# ---
# comments: true
# layout: notebook
# title: Jiangsu cuisine
# description: Discription about Jiangsu cuisine
# type: tangibles
# courses: { csp: {week: 0} }
# categories: [C4.1]
# tags:
# - APCSP
# - CODE CODE CODE
# ---

# %% [markdown]
# ## 5. Jiangsu cuisine
# ![image.png](attachment:image.png)
